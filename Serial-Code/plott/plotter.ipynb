# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dt1 = pd.read_csv("huffmanCoding.csv")
dt2 = pd.read_csv("AdaptivehuffmanCoding.csv")
plt.plot(dt1["Characters"], dt1["Time(s)"])
plt.plot(dt2["Characters"], dt2["Time(s)"])
plt.legend(["Huffman", "Adaptive Huffman"])
plt.ylabel('Time(s)')
plt.xlabel('No of Characters')
plt.grid(True)
plt.semilogx()
# Out:
# []

# %%
legends = ["Serial"]
dt2 = pd.read_csv("AdaptivehuffmanCoding.csv")
plt.plot(dt2["Characters"], dt2["Time(s)"])

for i in range(2,13,2):
    df = pd.read_csv("AdaptivehuffmanCoding_p_"+ "{}".format(i) + ".csv")
    plt.plot(df["Characters"], df["Time(s)"])
    plt.semilogx()
    legends.append("processors = {}".format(i))
plt.legend(legends)
plt.ylabel('Time(s)')
plt.xlabel('No of Characters')
plt.grid(True)
